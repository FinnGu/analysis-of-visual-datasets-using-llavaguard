# %%
import pandas as pd

df = pd.read_csv('/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_logprobs/results_7B_laion2B-en_test_10000_336_25_02_20_01/token_logprobs/batch_0/00003990.csv')

display(df.head(20))
# Out:
#    logprob_1_token  logprob_1_logprob logprob_1_linprob logprob_2_token  \
# 0              {\n      -8.463824e-06           100.0 %               {
# 1                       -1.192093e-07           100.0 %
# 2                "       0.000000e+00           100.0 %               '
# 3           rating      -3.099437e-06           100.0 %          rating
# 4               ":      -4.768370e-07           100.0 %             "\n
# 5                "      -1.192093e-07           100.0 %            ""\n
# 6             Safe      -8.856903e-04           99.91 %          Unsafe
# 7             ",\n      -1.049036e-05           100.0 %             "\n
# 8                        0.000000e+00           100.0 %
# 9                "       0.000000e+00           100.0 %              "_
# 10        category      -1.311301e-06           100.0 %        category
# 11              ":      -1.192093e-07           100.0 %              ':
# ...
