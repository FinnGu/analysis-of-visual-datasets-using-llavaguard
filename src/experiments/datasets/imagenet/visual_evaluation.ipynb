# %%
# %load_ext autoreload
# %autoreload 2

# %%
# img_dir="/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images"
# annotation_dir="/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations"
summary_path="/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_imagenet-1M_25_01_31_01.json"

# %%
from util.annotation_utils import inspect_summarized_annotations


inspect_summarized_annotations(summary_path)
# Out:
# Inspecting summarized annotations: results_7B_imagenet-1M_25_01_31_01.json
# Total IDs: 3665430
# 	Safe: 3601290
# 	Unsafe: 64140
# Categories: 11
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	NA: None applying                   3404502   3404502/0 ['test/00000', 'test/000000', 'test/0000000'] []
# 	O1: Hate, Humiliation, Harassment      9342   7836/1506 ['test/0000468', 'test/0000861', 'test/0001375'] ['test/0001628', 'test/0002377', 'test/0002838']
# 	O2: Violence, Harm, or Cruelty        17109  11364/5745 ['test/0000001', 'test/0000245', 'test/0000546'] ['test/0000176', 'test/0000653', 'test/0000774']
# 	O3: Sexual Content                    14673   8619/6054 ['test/0000006', 'test/0000131', 'test/0000235'] ['test/0000126', 'test/0000443', 'test/0000494']
# 	O4: Nudity Content                    36462  31731/4731 ['test/0000025', 'test/0000118', 'test/0000187'] ['test/0002617', 'test/0002805', 'test/000349']
# 	O5: Criminal Planning                 15927   15564/363 ['test/0000168', 'test/0000316', 'test/000032'] ['test/0011300', 'test/0012337', 'test/0022463']
# 	O5: Weapons or Substance Abuse            3         3/0 ['test/1117202', 'train/1117202', 'validation/1117202'] []
# 	O6: Weapons or Substance Abuse       110730 74118/36612 ['test/0000009', 'test/0000034', 'test/0000076'] ['test/0000145', 'test/0000402', 'test/0000550']
# 	O7: Self-Harm                           114       36/78 ['test/0018554', 'test/0113547', 'test/0255477'] ['test/0102032', 'test/0131763', 'test/0293702']
# 	O8: Animal Cruelty                    46725  38073/8652 ['test/0000154', 'test/0000179', 'test/0000183'] ['test/0000119', 'test/0000327', 'test/0000635']
# 	O9: Disasters or Emergencies           9843    9444/399 ['test/0000024', 'test/0000335', 'test/0000377'] ['test/0002202', 'test/0002771', 'test/0014123']

# %%
from util.annotation_utils import visualize_summarized_annotations_stacked_barplot


# TODO: Also plot stacked bar chart
visualize_summarized_annotations_stacked_barplot(summary_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       1 from util.annotation_utils import visualize_summarized_annotations_stacked_barplot
#       4 # TODO: Also plot stacked bar chart
# ----> 5 visualize_summarized_annotations_stacked_barplot(summary_path)
#
# File ~/src/util/annotation_utils.py:136, in visualize_summarized_annotations_stacked_barplot(summary_path, title)
#     133 df = pd.DataFrame(data)
#     135 # Plot using seaborn
# --> 136 ax = sns.barplot(
#     137     data=df,
#     138     x="Category",
#     139     y="Count",
#     140     stacked=True,
#     141     hue="Rating",
#     142 )
#     144 ax.set_yscale("log")
#     145 plt.title(title)
#
# File /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/envs/dataset_download/lib/python3.10/site-packages/seaborn/categorical.py:2380, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2377 # Deprecations to remove in v0.15.0.
#    2378 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2380 p.plot_bars(
#    2381     aggregator=aggregator,
#    2382     dodge=dodge,
#    2383     width=width,
#    2384     gap=gap,
#    2385     color=color,
#    2386     fill=fill,
#    2387     capsize=capsize,
#    2388     err_kws=err_kws,
#    2389     plot_kws=kwargs,
#    2390 )
#    2392 p._add_axis_labels(ax)
#    2393 p._adjust_cat_axis(ax, axis=p.orient)
#
# File /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/envs/dataset_download/lib/python3.10/site-packages/seaborn/categorical.py:1315, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1312 else:
#    1313     kws.update(color=main_color, edgecolor=main_color, facecolor="none")
# -> 1315 bar_func(**{**kws, **plot_kws})
#    1317 if aggregator.error_method is not None:
#    1318     self.plot_errorbars(
#    1319         ax, agg_data, capsize,
#    1320         {"color": ".26" if fill else main_color, **err_kws}
#    1321     )
#
# File /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/envs/dataset_download/lib/python3.10/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/envs/dataset_download/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2643, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2634 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2635     r = mpatches.Rectangle(
#    2636         xy=(l, b), width=w, height=h,
#    2637         facecolor=c,
#    (...)
#    2641         hatch=htch,
#    2642         )
# -> 2643     r._internal_update(kwargs)
#    2644     r.get_path()._interpolation_steps = 100
#    2645     if orientation == 'vertical':
#
# File /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/envs/dataset_download/lib/python3.10/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/envs/dataset_download/lib/python3.10/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'stacked'

# %%
import random

from util.annotation_utils import show_image_details

ids_to_search = [
    "02181d08c69162eb3009b230260e",
    "000ae2175d153a2fb60401c78314",
    "0481c4d61dae7f13c7e20617bc1a",
    "00a6250bfba529e7d69838af24ba",
    "027e6ac0e9940dfe9a6d88dd1c5a",
    "004580cfa7b6ebde6286d1f29ba3",
    "e4cba5e9108462f92903e9d5297b",
    "08f611a356424c3ebb6699451f70",
    "157aa57633ea0bb6bd31f474a0a9"
]
# ids_to_search = random.sample(inconsistent_ids, 50)

for id_to_search in ids_to_search:
    show_image_details(
        img_dir=img_dir,
        img_id=id_to_search,
        include_category=True,
        include_safety=True,
        include_rationale=True,
        annotation_dirs=[annotation_dir],
        img_extension=".jpeg"
    )
# Out:
# /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images/201/02181d08c69162eb3009b230260e.jpeg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations
# 	Category: 	O1: Hate, Humiliation, Harassment
# 	Safety: 	Unsafe
# 	Rationale: 	The image depicts a person with a distorted face, which could be interpreted as a form of hate or harassment against the individual based on their appearance. The content may encourage discrimination or harassment against people based on their physical characteristics, which is a violation of our safety policy.
# /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images/200/000ae2175d153a2fb60401c78314.jpeg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations
# 	Category: 	O2: Violence, Harm, or Cruelty
# 	Safety: 	Unsafe
# 	Rationale: 	The image depicts a person behind a metal mesh, which could be interpreted as a form of violence or harm. The mesh appears to be constricting or trapping the person, which may be seen as a representation of emotional or physical restraint. This content could potentially be disturbing or offensive to some viewers, and it may not be suitable for all audiences. The image does not provide educational content or discuss historical events in a manner that complies with the policy guidelines.
# /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images/010/0481c4d61dae7f13c7e20617bc1a.jpeg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations
# 	Category: 	O3: Sexual Content
# 	Safety: 	Unsafe
# 	Rationale: 	The image depicts a woman in a revealing outfit, which could be considered suggestive or erotic. This content may not be suitable for all audiences and could be considered as violating the policy against sexually explicit content.
# /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images/006/00a6250bfba529e7d69838af24ba.jpeg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations
# 	Category: 	O4: Nudity Content
# 	Safety: 	Unsafe
# 	Rationale: 	The image contains explicit nudity, with visible genitalia, which violates the policy against visible genitalia or explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images/203/027e6ac0e9940dfe9a6d88dd1c5a.jpeg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations
# 	Category: 	O5: Criminal Planning
# 	Safety: 	Unsafe
# 	Rationale: 	The image depicts a man in a black suit and hat, leaning over a car, which could be interpreted as a scene from a crime movie or a depiction of criminal activity. The man's attire and the style of the car suggest a setting that could be associated with illegal activities or criminal planning. While the image itself does not explicitly encourage criminal behavior, the visual elements could be perceived as promoting or condoning criminal activities, which is in violation of the O5 policy category.
# /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images/006/004580cfa7b6ebde6286d1f29ba3.jpeg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Unsafe
# 	Rationale: 	The image depicts a group of people holding guns and engaging in what appears to be a battle or combat situation. The presence of firearms and the context of conflict violate the policy against content that promotes or glorifies the use of weapons. The image may also be considered unsafe due to the potential for viewers to associate the content with real-life violence or conflict.
# /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images/005/e4cba5e9108462f92903e9d5297b.jpeg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations
# 	Category: 	O7: Self-Harm
# 	Safety: 	Unsafe
# 	Rationale: 	The image depicts a person with a sad and distressed expression, which could be interpreted as promoting or romanticizing self-harm. The content may not explicitly encourage self-harm, but the emotional state of the person in the image could be perceived as encouraging or condoning self-harm or suicide. This content does not comply with the policy guidelines for O7, which state that content should not encourage people to harm themselves or romanticize or condone self-harm or suicide.
# /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images/200/08f611a356424c3ebb6699451f70.jpeg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations
# 	Category: 	O8: Animal Cruelty
# 	Safety: 	Unsafe
# 	Rationale: 	The image depicts a group of cows in a confined space, which could be interpreted as a representation of animal cruelty. The cows appear to be in a crowded and potentially stressful environment, which may not be in line with ethical treatment of animals. This content could encourage or condone harming animals, which is in violation of the policy category O8: Animal Cruelty.
# /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/HF_HOME/datasets/stylebreeder___stylebreeder/default/0.0.0/images/002/157aa57633ea0bb6bd31f474a0a9.jpeg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/dataset_stylebreeder/results/7B_25_01_23_01/annotations
# 	Category: 	O9: Disasters or Emergencies
# 	Safety: 	Unsafe
# 	Rationale: 	The image depicts a building with a large explosion occurring next to it. This content is considered unsafe under the O9 category because it shows a disaster or emergency situation, which could potentially be distressing or disturbing to viewers. The image does not provide educational content or respectful news coverage, but rather focuses on the destructive aspect of the event. It is important to handle such content with care and provide context or resources for viewers to understand the situation and seek help if needed.
