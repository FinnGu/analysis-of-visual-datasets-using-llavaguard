# %%
import pandas as pd

df = pd.read_json('datasets.json')

# %%
df[['name', 'year', 'is_download_complete', 'download_size_gb', 'is_inference_complete', 'avg_inferences_per_second', 'num_4_gpu_workers', 'time_inference', 'img_count', 'huggingface', 'github']].sort_values(by=['is_download_complete', 'img_count'])
# Out:
#                               name  year  is_download_complete  \
# 7           Open Images Dataset V6  2020                 False
# 9                         LAION-5B  2022                 False
# 1                         CIFAR-10  2009                  True
# 2                        CIFAR-100  2009                  True
# 4                           CelebA  2015                  True
# 6   VQA: Visual Question Answering  2015                  True
# 3                          MS COCO  2014                  True
# 0                         ImageNet  2009                  True
# 11                    Stylebreeder  2024                  True
# 8                            CC12M  2021                  True
# 5                             LSUN  2015                  True
# 10                     DataComp-1B  2023                  True
#
#     download_size_gb  is_inference_complete  avg_inferences_per_second  \
# 7                NaN                  False                        NaN
# ...
